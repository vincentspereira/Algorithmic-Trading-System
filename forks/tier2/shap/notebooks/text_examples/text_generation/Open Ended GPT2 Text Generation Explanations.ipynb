# %% [markdown]
# # Open Ended GPT2 Text Generation Explanations

# %% [markdown]
# This notebook demonstrates how to get explanations for the output of gpt2 used for open ended text generation. In this demo, we use the pretrained gpt2 model provided by hugging face (https://huggingface.co/gpt2) to explain the generated text by gpt2. We further showcase how to get explanations for custom output generated text and plot global input token importances for any output generated token.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

import shap

# %% [markdown]
# ### Load model and tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2", use_fast=True)
model = AutoModelForCausalLM.from_pretrained("gpt2").cuda()

# %% [markdown]
# Below, we set certain model configurations. We need to define if the model is a decoder or encoder-decoder.
# This can be set through the 'is_decoder' or 'is_encoder_decoder' param in model's config file.
# We can also set custom model generation parameters which will be used during the output text generation decoding process.

# %%
# set model decoder to true
model.config.is_decoder = True
# set text-generation params under task_specific_params
model.config.task_specific_params["text-generation"] = {
    "do_sample": True,
    "max_length": 50,
    "temperature": 0.7,
    "top_k": 50,
    "no_repeat_ngram_size": 2,
}

# %% [markdown]
# ### Define initial text

# %%
s = ["I enjoy walking with my cute dog"]

# %% [markdown]
# ### Create an explainer object and compute the SHAP values

# %%
explainer = shap.Explainer(model, tokenizer)
shap_values = explainer(s)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %% [markdown]
# ### Visualize shap explanations

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_snecdbxeudrnckmfgliz = '_tp_snecdbxeudrnckmfgliz_output_0';
#     document._zoom_snecdbxeudrnckmfgliz = undefined;
#     function _output_onclick_snecdbxeudrnckmfgliz(i) {
#         var next_id = undefined;
#
#         if (document._zoom_snecdbxeudrnckmfgliz !== undefined) {
#             document.getElementById(document._zoom_snecdbxeudrnckmfgliz+ '_zoom').style.display = 'none';
#
#             if (document._zoom_snecdbxeudrnckmfgliz === '_tp_snecdbxeudrnckmfgliz_output_' + i) {
#                 document.getElementById(document._zoom_snecdbxeudrnckmfgliz).style.display = 'block';
#                 document.getElementById(document._zoom_snecdbxeudrnckmfgliz+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_snecdbxeudrnckmfgliz).style.display = 'none';
#                 document.getElementById(document._zoom_snecdbxeudrnckmfgliz+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_snecdbxeudrnckmfgliz !== '_tp_snecdbxeudrnckmfgliz_output_' + i) {
#             next_id = '_tp_snecdbxeudrnckmfgliz_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_snecdbxeudrnckmfgliz = next_id;
#     }
#     function _output_onmouseover_snecdbxeudrnckmfgliz(i, el) {
#         if (document._zoom_snecdbxeudrnckmfgliz !== undefined) { return; }
#         if (document._hover_snecdbxeudrnckmfgliz !== undefined) {
#             document.getElementById(document._hover_snecdbxeudrnckmfgliz + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_snecdbxeudrnckmfgliz).style.display = 'none';
#         }
#         document.getElementById('_tp_snecdbxeudrnckmfgliz_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_snecdbxeudrnckmfgliz = '_tp_snecdbxeudrnckmfgliz_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_0_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(0)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(0, this);">,</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_1_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(1)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(1, this);">but</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_2_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(2)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(2, this);">I</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_3_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(3)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(3, this);">'m</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_4_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(4)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(4, this);">not</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_5_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(5)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(5, this);">sure</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_6_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(6)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(6, this);">if</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_7_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(7)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(7, this);">I</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_8_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(8)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(8, this);">'ll</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_9_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(9)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(9, this);">ever</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_10_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(10)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(10, this);">be</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_11_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(11)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(11, this);">able</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_snecdbxeudrnckmfgliz_output_12_name"
#     onclick="_output_onclick_snecdbxeudrnckmfgliz(12)"
#     onmouseover="_output_onmouseover_snecdbxeudrnckmfgliz(12, this);">to</div><br><br><div id='_tp_snecdbxeudrnckmfgliz_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="46.51600778831895%" y1="33" x2="46.51600778831895%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="46.51600778831895%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">0</text><line x1="30.911339968033506%" y1="33" x2="30.911339968033506%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="30.911339968033506%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-2</text><line x1="15.306672147748062%" y1="33" x2="15.306672147748062%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="15.306672147748062%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="62.120675608604394%" y1="33" x2="62.120675608604394%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="62.120675608604394%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">2</text><line x1="77.72534342888983%" y1="33" x2="77.72534342888983%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="77.72534342888983%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">4</text><line x1="14.921191694890155%" y1="33" x2="14.921191694890155%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="14.921191694890155%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-4.04941</text><text x="14.921191694890155%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4.04941</text><text x="14.921191694890155%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="36.56632187057016%" y1="33" x2="36.56632187057016%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.56632187057016%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-1.27522</text><text x="36.566321

# %% [markdown]
# ### Another example...

# %%
s = ["Scientists confirmed the worst possible outcome: the massive asteroid will collide with Earth"]

# %%
explainer = shap.Explainer(model, tokenizer)
shap_values = explainer(s)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_xjhgkjdhwjlcpnjffvzv = '_tp_xjhgkjdhwjlcpnjffvzv_output_0';
#     document._zoom_xjhgkjdhwjlcpnjffvzv = undefined;
#     function _output_onclick_xjhgkjdhwjlcpnjffvzv(i) {
#         var next_id = undefined;
#
#         if (document._zoom_xjhgkjdhwjlcpnjffvzv !== undefined) {
#             document.getElementById(document._zoom_xjhgkjdhwjlcpnjffvzv+ '_zoom').style.display = 'none';
#
#             if (document._zoom_xjhgkjdhwjlcpnjffvzv === '_tp_xjhgkjdhwjlcpnjffvzv_output_' + i) {
#                 document.getElementById(document._zoom_xjhgkjdhwjlcpnjffvzv).style.display = 'block';
#                 document.getElementById(document._zoom_xjhgkjdhwjlcpnjffvzv+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_xjhgkjdhwjlcpnjffvzv).style.display = 'none';
#                 document.getElementById(document._zoom_xjhgkjdhwjlcpnjffvzv+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_xjhgkjdhwjlcpnjffvzv !== '_tp_xjhgkjdhwjlcpnjffvzv_output_' + i) {
#             next_id = '_tp_xjhgkjdhwjlcpnjffvzv_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_xjhgkjdhwjlcpnjffvzv = next_id;
#     }
#     function _output_onmouseover_xjhgkjdhwjlcpnjffvzv(i, el) {
#         if (document._zoom_xjhgkjdhwjlcpnjffvzv !== undefined) { return; }
#         if (document._hover_xjhgkjdhwjlcpnjffvzv !== undefined) {
#             document.getElementById(document._hover_xjhgkjdhwjlcpnjffvzv + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_xjhgkjdhwjlcpnjffvzv).style.display = 'none';
#         }
#         document.getElementById('_tp_xjhgkjdhwjlcpnjffvzv_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_xjhgkjdhwjlcpnjffvzv = '_tp_xjhgkjdhwjlcpnjffvzv_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_xjhgkjdhwjlcpnjffvzv_output_0_name"
#     onclick="_output_onclick_xjhgkjdhwjlcpnjffvzv(0)"
#     onmouseover="_output_onmouseover_xjhgkjdhwjlcpnjffvzv(0, this);">in</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_xjhgkjdhwjlcpnjffvzv_output_1_name"
#     onclick="_output_onclick_xjhgkjdhwjlcpnjffvzv(1)"
#     onmouseover="_output_onmouseover_xjhgkjdhwjlcpnjffvzv(1, this);">the</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_xjhgkjdhwjlcpnjffvzv_output_2_name"
#     onclick="_output_onclick_xjhgkjdhwjlcpnjffvzv(2)"
#     onmouseover="_output_onmouseover_xjhgkjdhwjlcpnjffvzv(2, this);">coming</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_xjhgkjdhwjlcpnjffvzv_output_3_name"
#     onclick="_output_onclick_xjhgkjdhwjlcpnjffvzv(3)"
#     onmouseover="_output_onmouseover_xjhgkjdhwjlcpnjffvzv(3, this);">days</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_xjhgkjdhwjlcpnjffvzv_output_4_name"
#     onclick="_output_onclick_xjhgkjdhwjlcpnjffvzv(4)"
#     onmouseover="_output_onmouseover_xjhgkjdhwjlcpnjffvzv(4, this);">.</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_xjhgkjdhwjlcpnjffvzv_output_5_name"
#     onclick="_output_onclick_xjhgkjdhwjlcpnjffvzv(5)"
#     onmouseover="_output_onmouseover_xjhgkjdhwjlcpnjffvzv(5, this);"></div><br><br><div id='_tp_xjhgkjdhwjlcpnjffvzv_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="52.831803693063776%" y1="33" x2="52.831803693063776%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="52.831803693063776%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.12817877915349%" y1="33" x2="34.12817877915349%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.12817877915349%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="15.424553865243206%" y1="33" x2="15.424553865243206%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="15.424553865243206%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="71.53542860697405%" y1="33" x2="71.53542860697405%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="71.53542860697405%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-1</text><line x1="90.23905352088434%" y1="33" x2="90.23905352088434%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="90.23905352088434%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">1</text><line x1="36.56341017484563%" y1="33" x2="36.56341017484563%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="36.56341017484563%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-4.7396</text><text x="36.56341017484563%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4.7396</text><text x="36.56341017484563%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="64.63007892708046%" y1="33" x2="64.63007892708046%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="64.63007892708046%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-1.7384</text><text x="64.63007892708046%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-1.7384</text><text x="64.63007892708046%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">in</tspan>(inputs)</text><rect x="24.640849088733386%" width="39.989229838347086%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="51.20269472803299%" x2="64.63007892708046%" y1="60" y2="60" id="_fb_qtkkucrqnzvcnvmrirlz_ind_13" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="57.91638682755672%" y="71" font-size="12px" id="_fs_qtkkucrqnzvcnvmrirlz_ind_13" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">1.436</text><svg x="51.20269472803299%" y="40" height="20" width="13.427384199047474%">  <svg x="0" y="0" width="100%" height="100%">    <text x="50%" y="9" font-size="12px" fill="rgb(255,255,255)" dominant-baseline="middle" text-anchor="middle">Earth</text>  </svg></svg><line x1="39.235169377753294%" x2="51.20269472803299%" y1="60" y2="60" id="_fb_qtkkucrqnzvcnvmrirlz_ind_11" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="45.21893205289314%" y="71" font-size="12px" id="_fs_qtkkucrqnzvcnvmrirlz_ind_11" fill="rgb(255.0, 0.0, 81.08083606031792)" style="opacity: 0" dominant-baseline="middle" text-anchor="middle">1.28</text> ...

# %% [markdown]
# ##  Custom text generation and debugging biased outputs

# %% [markdown]
# Below we demonstrate the process of how to explain the liklihood of generating a particular output sentence given an input sentence using the model. <br><br>
# For example, we ask a question:<br>
# Which country's inhabitant (target) in the sentence "I know many people who are [<b>target</b>]." would have a high liklilhood of generating the token "vodka" in the output sentence "They love their <b>vodka</b>!" ?
# <br><br>
# For this, we first define input-output sentence pairs

# %%
# define input
x = [
    "I know many people who are Russian.",
    "I know many people who are Greek.",
    "I know many people who are Australian.",
    "I know many people who are American.",
    "I know many people who are Italian.",
    "I know many people who are Spanish.",
    "I know many people who are German.",
    "I know many people who are Indian.",
]

# %%
# define output
y = [
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
    "They love their vodka!",
]

# %% [markdown]
# We wrap the model with a Teacher Forcing scoring class and create a Text masker

# %%
teacher_forcing_model = shap.models.TeacherForcing(model, tokenizer)
masker = shap.maskers.Text(tokenizer, mask_token="...", collapse_mask_token=True)

# %% [markdown]
# Create an explainer...

# %%
explainer = shap.Explainer(teacher_forcing_model, masker)

# %% [markdown]
# Generate SHAP explanation values!

# %%
shap_values = explainer(x, y)

# %% [markdown]
# Now that we have generated the SHAP values, we can have a look at the contribution of tokens in the input driving the token "vodka" in the output sentence using the text plot. <br><br>
# <b>Note:</b> The red color indicates a positive contribution while the blue color indicates negative contribution and the intensity of the color shows its strength in the respective direction.

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_edcstlnojlzvwvueemgi = '_tp_edcstlnojlzvwvueemgi_output_0';
#     document._zoom_edcstlnojlzvwvueemgi = undefined;
#     function _output_onclick_edcstlnojlzvwvueemgi(i) {
#         var next_id = undefined;
#
#         if (document._zoom_edcstlnojlzvwvueemgi !== undefined) {
#             document.getElementById(document._zoom_edcstlnojlzvwvueemgi+ '_zoom').style.display = 'none';
#
#             if (document._zoom_edcstlnojlzvwvueemgi === '_tp_edcstlnojlzvwvueemgi_output_' + i) {
#                 document.getElementById(document._zoom_edcstlnojlzvwvueemgi).style.display = 'block';
#                 document.getElementById(document._zoom_edcstlnojlzvwvueemgi+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_edcstlnojlzvwvueemgi).style.display = 'none';
#                 document.getElementById(document._zoom_edcstlnojlzvwvueemgi+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_edcstlnojlzvwvueemgi !== '_tp_edcstlnojlzvwvueemgi_output_' + i) {
#             next_id = '_tp_edcstlnojlzvwvueemgi_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_edcstlnojlzvwvueemgi = next_id;
#     }
#     function _output_onmouseover_edcstlnojlzvwvueemgi(i, el) {
#         if (document._zoom_edcstlnojlzvwvueemgi !== undefined) { return; }
#         if (document._hover_edcstlnojlzvwvueemgi !== undefined) {
#             document.getElementById(document._hover_edcstlnojlzvwvueemgi + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_edcstlnojlzvwvueemgi).style.display = 'none';
#         }
#         document.getElementById('_tp_edcstlnojlzvwvueemgi_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_edcstlnojlzvwvueemgi = '_tp_edcstlnojlzvwvueemgi_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_edcstlnojlzvwvueemgi_output_0_name"
#     onclick="_output_onclick_edcstlnojlzvwvueemgi(0)"
#     onmouseover="_output_onmouseover_edcstlnojlzvwvueemgi(0, this);">They</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_edcstlnojlzvwvueemgi_output_1_name"
#     onclick="_output_onclick_edcstlnojlzvwvueemgi(1)"
#     onmouseover="_output_onmouseover_edcstlnojlzvwvueemgi(1, this);">love</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_edcstlnojlzvwvueemgi_output_2_name"
#     onclick="_output_onclick_edcstlnojlzvwvueemgi(2)"
#     onmouseover="_output_onmouseover_edcstlnojlzvwvueemgi(2, this);">their</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_edcstlnojlzvwvueemgi_output_3_name"
#     onclick="_output_onclick_edcstlnojlzvwvueemgi(3)"
#     onmouseover="_output_onmouseover_edcstlnojlzvwvueemgi(3, this);">vodka</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_edcstlnojlzvwvueemgi_output_4_name"
#     onclick="_output_onclick_edcstlnojlzvwvueemgi(4)"
#     onmouseover="_output_onmouseover_edcstlnojlzvwvueemgi(4, this);">!</div><br><br><div id='_tp_edcstlnojlzvwvueemgi_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.82556457570859%" y1="33" x2="47.82556457570859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.82556457570859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="37.34987031040637%" y1="33" x2="37.34987031040637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.34987031040637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="26.87417604510414%" y1="33" x2="26.87417604510414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.87417604510414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="16.398481779801916%" y1="33" x2="16.398481779801916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.398481779801916%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="58.30125884101081%" y1="33" x2="58.30125884101081%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.30125884101081%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="68.77695310631303%" y1="33" x2="68.77695310631303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.77695310631303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="79.25264737161525%" y1="33" x2="79.25264737161525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.25264737161525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="89.72834163691748%" y1="33" x2="89.72834163691748%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.72834163691748%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.746878604975414%" y1="33" x2="34.746878604975414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.746878604975414%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="29.13149735235753%" y1="33" x2="29.13149735235753%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="29.13149735235753%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.78452</text><text x="29.13149735235753%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-8.78452</text><text x="29.13149735235753%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">They</tspan>(inputs)</text><rect x="22.385582079463617%" width="6.745915272893918%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="25.20167445735388%" x2="29.13149735235753%" y1="60" y2="60" id="_fb_dyoudzopwkzpyvsldcxm_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="27.166585904855708%" y="71" font-size="12px" id="_fs_dyoudzopwkzpyvsldcxm_ind_7" fill="rgb ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[1]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_qmiebjeuflzomxztsfrp = '_tp_qmiebjeuflzomxztsfrp_output_0';
#     document._zoom_qmiebjeuflzomxztsfrp = undefined;
#     function _output_onclick_qmiebjeuflzomxztsfrp(i) {
#         var next_id = undefined;
#
#         if (document._zoom_qmiebjeuflzomxztsfrp !== undefined) {
#             document.getElementById(document._zoom_qmiebjeuflzomxztsfrp+ '_zoom').style.display = 'none';
#
#             if (document._zoom_qmiebjeuflzomxztsfrp === '_tp_qmiebjeuflzomxztsfrp_output_' + i) {
#                 document.getElementById(document._zoom_qmiebjeuflzomxztsfrp).style.display = 'block';
#                 document.getElementById(document._zoom_qmiebjeuflzomxztsfrp+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_qmiebjeuflzomxztsfrp).style.display = 'none';
#                 document.getElementById(document._zoom_qmiebjeuflzomxztsfrp+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_qmiebjeuflzomxztsfrp !== '_tp_qmiebjeuflzomxztsfrp_output_' + i) {
#             next_id = '_tp_qmiebjeuflzomxztsfrp_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_qmiebjeuflzomxztsfrp = next_id;
#     }
#     function _output_onmouseover_qmiebjeuflzomxztsfrp(i, el) {
#         if (document._zoom_qmiebjeuflzomxztsfrp !== undefined) { return; }
#         if (document._hover_qmiebjeuflzomxztsfrp !== undefined) {
#             document.getElementById(document._hover_qmiebjeuflzomxztsfrp + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_qmiebjeuflzomxztsfrp).style.display = 'none';
#         }
#         document.getElementById('_tp_qmiebjeuflzomxztsfrp_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_qmiebjeuflzomxztsfrp = '_tp_qmiebjeuflzomxztsfrp_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_qmiebjeuflzomxztsfrp_output_0_name"
#     onclick="_output_onclick_qmiebjeuflzomxztsfrp(0)"
#     onmouseover="_output_onmouseover_qmiebjeuflzomxztsfrp(0, this);">They</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_qmiebjeuflzomxztsfrp_output_1_name"
#     onclick="_output_onclick_qmiebjeuflzomxztsfrp(1)"
#     onmouseover="_output_onmouseover_qmiebjeuflzomxztsfrp(1, this);">love</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_qmiebjeuflzomxztsfrp_output_2_name"
#     onclick="_output_onclick_qmiebjeuflzomxztsfrp(2)"
#     onmouseover="_output_onmouseover_qmiebjeuflzomxztsfrp(2, this);">their</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_qmiebjeuflzomxztsfrp_output_3_name"
#     onclick="_output_onclick_qmiebjeuflzomxztsfrp(3)"
#     onmouseover="_output_onmouseover_qmiebjeuflzomxztsfrp(3, this);">vodka</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_qmiebjeuflzomxztsfrp_output_4_name"
#     onclick="_output_onclick_qmiebjeuflzomxztsfrp(4)"
#     onmouseover="_output_onmouseover_qmiebjeuflzomxztsfrp(4, this);">!</div><br><br><div id='_tp_qmiebjeuflzomxztsfrp_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.82556457570859%" y1="33" x2="47.82556457570859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.82556457570859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="37.34987031040637%" y1="33" x2="37.34987031040637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.34987031040637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="26.87417604510414%" y1="33" x2="26.87417604510414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.87417604510414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="16.398481779801916%" y1="33" x2="16.398481779801916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.398481779801916%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="58.30125884101081%" y1="33" x2="58.30125884101081%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.30125884101081%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="68.77695310631303%" y1="33" x2="68.77695310631303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.77695310631303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="79.25264737161525%" y1="33" x2="79.25264737161525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.25264737161525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="89.72834163691748%" y1="33" x2="89.72834163691748%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.72834163691748%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.746878604975414%" y1="33" x2="34.746878604975414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.746878604975414%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="27.411642813546283%" y1="33" x2="27.411642813546283%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="27.411642813546283%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.94869</text><text x="27.411642813546283%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-8.94869</text><text x="27.411642813546283%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">They</tspan>(inputs)</text><rect x="19.725485599202116%" width="7.686157214344161%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="23.361645032333296%" x2="27.411642813546283%" y1="60" y2="60" id="_fb_ifbrknyymbknubiqjqgk_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="25.38664392293979%" y="71" font-size="12px" id="_fs_ifbrknyymbknubiqjqgk_ind_7" fil ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[2]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_vlaixyswvmakeolpxxaj = '_tp_vlaixyswvmakeolpxxaj_output_0';
#     document._zoom_vlaixyswvmakeolpxxaj = undefined;
#     function _output_onclick_vlaixyswvmakeolpxxaj(i) {
#         var next_id = undefined;
#
#         if (document._zoom_vlaixyswvmakeolpxxaj !== undefined) {
#             document.getElementById(document._zoom_vlaixyswvmakeolpxxaj+ '_zoom').style.display = 'none';
#
#             if (document._zoom_vlaixyswvmakeolpxxaj === '_tp_vlaixyswvmakeolpxxaj_output_' + i) {
#                 document.getElementById(document._zoom_vlaixyswvmakeolpxxaj).style.display = 'block';
#                 document.getElementById(document._zoom_vlaixyswvmakeolpxxaj+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_vlaixyswvmakeolpxxaj).style.display = 'none';
#                 document.getElementById(document._zoom_vlaixyswvmakeolpxxaj+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_vlaixyswvmakeolpxxaj !== '_tp_vlaixyswvmakeolpxxaj_output_' + i) {
#             next_id = '_tp_vlaixyswvmakeolpxxaj_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_vlaixyswvmakeolpxxaj = next_id;
#     }
#     function _output_onmouseover_vlaixyswvmakeolpxxaj(i, el) {
#         if (document._zoom_vlaixyswvmakeolpxxaj !== undefined) { return; }
#         if (document._hover_vlaixyswvmakeolpxxaj !== undefined) {
#             document.getElementById(document._hover_vlaixyswvmakeolpxxaj + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_vlaixyswvmakeolpxxaj).style.display = 'none';
#         }
#         document.getElementById('_tp_vlaixyswvmakeolpxxaj_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_vlaixyswvmakeolpxxaj = '_tp_vlaixyswvmakeolpxxaj_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_vlaixyswvmakeolpxxaj_output_0_name"
#     onclick="_output_onclick_vlaixyswvmakeolpxxaj(0)"
#     onmouseover="_output_onmouseover_vlaixyswvmakeolpxxaj(0, this);">They</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_vlaixyswvmakeolpxxaj_output_1_name"
#     onclick="_output_onclick_vlaixyswvmakeolpxxaj(1)"
#     onmouseover="_output_onmouseover_vlaixyswvmakeolpxxaj(1, this);">love</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_vlaixyswvmakeolpxxaj_output_2_name"
#     onclick="_output_onclick_vlaixyswvmakeolpxxaj(2)"
#     onmouseover="_output_onmouseover_vlaixyswvmakeolpxxaj(2, this);">their</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_vlaixyswvmakeolpxxaj_output_3_name"
#     onclick="_output_onclick_vlaixyswvmakeolpxxaj(3)"
#     onmouseover="_output_onmouseover_vlaixyswvmakeolpxxaj(3, this);">vodka</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_vlaixyswvmakeolpxxaj_output_4_name"
#     onclick="_output_onclick_vlaixyswvmakeolpxxaj(4)"
#     onmouseover="_output_onmouseover_vlaixyswvmakeolpxxaj(4, this);">!</div><br><br><div id='_tp_vlaixyswvmakeolpxxaj_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.82556457570859%" y1="33" x2="47.82556457570859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.82556457570859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="37.34987031040637%" y1="33" x2="37.34987031040637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.34987031040637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="26.87417604510414%" y1="33" x2="26.87417604510414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.87417604510414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="16.398481779801916%" y1="33" x2="16.398481779801916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.398481779801916%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="58.30125884101081%" y1="33" x2="58.30125884101081%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.30125884101081%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="68.77695310631303%" y1="33" x2="68.77695310631303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.77695310631303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="79.25264737161525%" y1="33" x2="79.25264737161525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.25264737161525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="89.72834163691748%" y1="33" x2="89.72834163691748%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.72834163691748%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.746878604975414%" y1="33" x2="34.746878604975414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.746878604975414%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="30.26807807474488%" y1="33" x2="30.26807807474488%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="30.26807807474488%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.67602</text><text x="30.26807807474488%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-8.67602</text><text x="30.26807807474488%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">They</tspan>(inputs)</text><rect x="21.25382905559283%" width="9.014249019152047%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="22.925251369477408%" x2="30.26807807474488%" y1="60" y2="60" id="_fb_ejblecnyphbovspnhxdw_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="26.596664722111143%" y="71" font-size="12px" id="_fs_ejblecnyphbovspnhxdw_ind_7" fill="rgb ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[3]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_agjcoffhicupywophbrx = '_tp_agjcoffhicupywophbrx_output_0';
#     document._zoom_agjcoffhicupywophbrx = undefined;
#     function _output_onclick_agjcoffhicupywophbrx(i) {
#         var next_id = undefined;
#
#         if (document._zoom_agjcoffhicupywophbrx !== undefined) {
#             document.getElementById(document._zoom_agjcoffhicupywophbrx+ '_zoom').style.display = 'none';
#
#             if (document._zoom_agjcoffhicupywophbrx === '_tp_agjcoffhicupywophbrx_output_' + i) {
#                 document.getElementById(document._zoom_agjcoffhicupywophbrx).style.display = 'block';
#                 document.getElementById(document._zoom_agjcoffhicupywophbrx+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_agjcoffhicupywophbrx).style.display = 'none';
#                 document.getElementById(document._zoom_agjcoffhicupywophbrx+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_agjcoffhicupywophbrx !== '_tp_agjcoffhicupywophbrx_output_' + i) {
#             next_id = '_tp_agjcoffhicupywophbrx_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_agjcoffhicupywophbrx = next_id;
#     }
#     function _output_onmouseover_agjcoffhicupywophbrx(i, el) {
#         if (document._zoom_agjcoffhicupywophbrx !== undefined) { return; }
#         if (document._hover_agjcoffhicupywophbrx !== undefined) {
#             document.getElementById(document._hover_agjcoffhicupywophbrx + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_agjcoffhicupywophbrx).style.display = 'none';
#         }
#         document.getElementById('_tp_agjcoffhicupywophbrx_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_agjcoffhicupywophbrx = '_tp_agjcoffhicupywophbrx_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_agjcoffhicupywophbrx_output_0_name"
#     onclick="_output_onclick_agjcoffhicupywophbrx(0)"
#     onmouseover="_output_onmouseover_agjcoffhicupywophbrx(0, this);">They</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_agjcoffhicupywophbrx_output_1_name"
#     onclick="_output_onclick_agjcoffhicupywophbrx(1)"
#     onmouseover="_output_onmouseover_agjcoffhicupywophbrx(1, this);">love</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_agjcoffhicupywophbrx_output_2_name"
#     onclick="_output_onclick_agjcoffhicupywophbrx(2)"
#     onmouseover="_output_onmouseover_agjcoffhicupywophbrx(2, this);">their</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_agjcoffhicupywophbrx_output_3_name"
#     onclick="_output_onclick_agjcoffhicupywophbrx(3)"
#     onmouseover="_output_onmouseover_agjcoffhicupywophbrx(3, this);">vodka</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_agjcoffhicupywophbrx_output_4_name"
#     onclick="_output_onclick_agjcoffhicupywophbrx(4)"
#     onmouseover="_output_onmouseover_agjcoffhicupywophbrx(4, this);">!</div><br><br><div id='_tp_agjcoffhicupywophbrx_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.82556457570859%" y1="33" x2="47.82556457570859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.82556457570859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="37.34987031040637%" y1="33" x2="37.34987031040637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.34987031040637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="26.87417604510414%" y1="33" x2="26.87417604510414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.87417604510414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="16.398481779801916%" y1="33" x2="16.398481779801916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.398481779801916%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="58.30125884101081%" y1="33" x2="58.30125884101081%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.30125884101081%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="68.77695310631303%" y1="33" x2="68.77695310631303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.77695310631303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="79.25264737161525%" y1="33" x2="79.25264737161525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.25264737161525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="89.72834163691748%" y1="33" x2="89.72834163691748%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.72834163691748%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.746878604975414%" y1="33" x2="34.746878604975414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.746878604975414%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="25.37865482866111%" y1="33" x2="25.37865482866111%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="25.37865482866111%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-9.14276</text><text x="25.37865482866111%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-9.14276</text><text x="25.37865482866111%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">They</tspan>(inputs)</text><rect x="19.57640421108959%" width="5.802250617571527%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="21.2930699288016%" x2="25.37865482866111%" y1="60" y2="60" id="_fb_iydkitmucaczgtoxgoab_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="23.335862378731356%" y="71" font-size="12px" id="_fs_iydkitmucaczgtoxgoab_ind_7" fill="rgb(2 ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[4]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_lpojqfjfkeqolqqakrqt = '_tp_lpojqfjfkeqolqqakrqt_output_0';
#     document._zoom_lpojqfjfkeqolqqakrqt = undefined;
#     function _output_onclick_lpojqfjfkeqolqqakrqt(i) {
#         var next_id = undefined;
#
#         if (document._zoom_lpojqfjfkeqolqqakrqt !== undefined) {
#             document.getElementById(document._zoom_lpojqfjfkeqolqqakrqt+ '_zoom').style.display = 'none';
#
#             if (document._zoom_lpojqfjfkeqolqqakrqt === '_tp_lpojqfjfkeqolqqakrqt_output_' + i) {
#                 document.getElementById(document._zoom_lpojqfjfkeqolqqakrqt).style.display = 'block';
#                 document.getElementById(document._zoom_lpojqfjfkeqolqqakrqt+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_lpojqfjfkeqolqqakrqt).style.display = 'none';
#                 document.getElementById(document._zoom_lpojqfjfkeqolqqakrqt+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_lpojqfjfkeqolqqakrqt !== '_tp_lpojqfjfkeqolqqakrqt_output_' + i) {
#             next_id = '_tp_lpojqfjfkeqolqqakrqt_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_lpojqfjfkeqolqqakrqt = next_id;
#     }
#     function _output_onmouseover_lpojqfjfkeqolqqakrqt(i, el) {
#         if (document._zoom_lpojqfjfkeqolqqakrqt !== undefined) { return; }
#         if (document._hover_lpojqfjfkeqolqqakrqt !== undefined) {
#             document.getElementById(document._hover_lpojqfjfkeqolqqakrqt + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_lpojqfjfkeqolqqakrqt).style.display = 'none';
#         }
#         document.getElementById('_tp_lpojqfjfkeqolqqakrqt_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_lpojqfjfkeqolqqakrqt = '_tp_lpojqfjfkeqolqqakrqt_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_lpojqfjfkeqolqqakrqt_output_0_name"
#     onclick="_output_onclick_lpojqfjfkeqolqqakrqt(0)"
#     onmouseover="_output_onmouseover_lpojqfjfkeqolqqakrqt(0, this);">They</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_lpojqfjfkeqolqqakrqt_output_1_name"
#     onclick="_output_onclick_lpojqfjfkeqolqqakrqt(1)"
#     onmouseover="_output_onmouseover_lpojqfjfkeqolqqakrqt(1, this);">love</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_lpojqfjfkeqolqqakrqt_output_2_name"
#     onclick="_output_onclick_lpojqfjfkeqolqqakrqt(2)"
#     onmouseover="_output_onmouseover_lpojqfjfkeqolqqakrqt(2, this);">their</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_lpojqfjfkeqolqqakrqt_output_3_name"
#     onclick="_output_onclick_lpojqfjfkeqolqqakrqt(3)"
#     onmouseover="_output_onmouseover_lpojqfjfkeqolqqakrqt(3, this);">vodka</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_lpojqfjfkeqolqqakrqt_output_4_name"
#     onclick="_output_onclick_lpojqfjfkeqolqqakrqt(4)"
#     onmouseover="_output_onmouseover_lpojqfjfkeqolqqakrqt(4, this);">!</div><br><br><div id='_tp_lpojqfjfkeqolqqakrqt_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.82556457570859%" y1="33" x2="47.82556457570859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.82556457570859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="37.34987031040637%" y1="33" x2="37.34987031040637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.34987031040637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="26.87417604510414%" y1="33" x2="26.87417604510414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.87417604510414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="16.398481779801916%" y1="33" x2="16.398481779801916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.398481779801916%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="58.30125884101081%" y1="33" x2="58.30125884101081%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.30125884101081%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="68.77695310631303%" y1="33" x2="68.77695310631303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.77695310631303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="79.25264737161525%" y1="33" x2="79.25264737161525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.25264737161525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="89.72834163691748%" y1="33" x2="89.72834163691748%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.72834163691748%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.746878604975414%" y1="33" x2="34.746878604975414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.746878604975414%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="26.007434352495423%" y1="33" x2="26.007434352495423%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.007434352495423%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-9.08274</text><text x="26.007434352495423%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-9.08274</text><text x="26.007434352495423%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">They</tspan>(inputs)</text><rect x="17.95692393768921%" width="8.050510414806206%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="21.524890503557955%" x2="26.007434352495423%" y1="60" y2="60" id="_fb_ucnhjhyvsaledssbattc_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="23.76616242802669%" y="71" font-size="12px" id="_fs_ucnhjhyvsaledssbattc_ind_7" fill ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[5]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_jtpdzxkhbnpitqjvvthg = '_tp_jtpdzxkhbnpitqjvvthg_output_0';
#     document._zoom_jtpdzxkhbnpitqjvvthg = undefined;
#     function _output_onclick_jtpdzxkhbnpitqjvvthg(i) {
#         var next_id = undefined;
#
#         if (document._zoom_jtpdzxkhbnpitqjvvthg !== undefined) {
#             document.getElementById(document._zoom_jtpdzxkhbnpitqjvvthg+ '_zoom').style.display = 'none';
#
#             if (document._zoom_jtpdzxkhbnpitqjvvthg === '_tp_jtpdzxkhbnpitqjvvthg_output_' + i) {
#                 document.getElementById(document._zoom_jtpdzxkhbnpitqjvvthg).style.display = 'block';
#                 document.getElementById(document._zoom_jtpdzxkhbnpitqjvvthg+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_jtpdzxkhbnpitqjvvthg).style.display = 'none';
#                 document.getElementById(document._zoom_jtpdzxkhbnpitqjvvthg+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_jtpdzxkhbnpitqjvvthg !== '_tp_jtpdzxkhbnpitqjvvthg_output_' + i) {
#             next_id = '_tp_jtpdzxkhbnpitqjvvthg_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_jtpdzxkhbnpitqjvvthg = next_id;
#     }
#     function _output_onmouseover_jtpdzxkhbnpitqjvvthg(i, el) {
#         if (document._zoom_jtpdzxkhbnpitqjvvthg !== undefined) { return; }
#         if (document._hover_jtpdzxkhbnpitqjvvthg !== undefined) {
#             document.getElementById(document._hover_jtpdzxkhbnpitqjvvthg + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_jtpdzxkhbnpitqjvvthg).style.display = 'none';
#         }
#         document.getElementById('_tp_jtpdzxkhbnpitqjvvthg_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_jtpdzxkhbnpitqjvvthg = '_tp_jtpdzxkhbnpitqjvvthg_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_jtpdzxkhbnpitqjvvthg_output_0_name"
#     onclick="_output_onclick_jtpdzxkhbnpitqjvvthg(0)"
#     onmouseover="_output_onmouseover_jtpdzxkhbnpitqjvvthg(0, this);">They</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_jtpdzxkhbnpitqjvvthg_output_1_name"
#     onclick="_output_onclick_jtpdzxkhbnpitqjvvthg(1)"
#     onmouseover="_output_onmouseover_jtpdzxkhbnpitqjvvthg(1, this);">love</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_jtpdzxkhbnpitqjvvthg_output_2_name"
#     onclick="_output_onclick_jtpdzxkhbnpitqjvvthg(2)"
#     onmouseover="_output_onmouseover_jtpdzxkhbnpitqjvvthg(2, this);">their</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_jtpdzxkhbnpitqjvvthg_output_3_name"
#     onclick="_output_onclick_jtpdzxkhbnpitqjvvthg(3)"
#     onmouseover="_output_onmouseover_jtpdzxkhbnpitqjvvthg(3, this);">vodka</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_jtpdzxkhbnpitqjvvthg_output_4_name"
#     onclick="_output_onclick_jtpdzxkhbnpitqjvvthg(4)"
#     onmouseover="_output_onmouseover_jtpdzxkhbnpitqjvvthg(4, this);">!</div><br><br><div id='_tp_jtpdzxkhbnpitqjvvthg_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.82556457570859%" y1="33" x2="47.82556457570859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.82556457570859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="37.34987031040637%" y1="33" x2="37.34987031040637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.34987031040637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="26.87417604510414%" y1="33" x2="26.87417604510414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.87417604510414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="16.398481779801916%" y1="33" x2="16.398481779801916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.398481779801916%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="58.30125884101081%" y1="33" x2="58.30125884101081%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.30125884101081%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="68.77695310631303%" y1="33" x2="68.77695310631303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.77695310631303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="79.25264737161525%" y1="33" x2="79.25264737161525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.25264737161525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="89.72834163691748%" y1="33" x2="89.72834163691748%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.72834163691748%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.746878604975414%" y1="33" x2="34.746878604975414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.746878604975414%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="26.093731585586724%" y1="33" x2="26.093731585586724%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.093731585586724%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-9.0745</text><text x="26.093731585586724%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-9.0745</text><text x="26.093731585586724%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">They</tspan>(inputs)</text><rect x="16.00344897929438%" width="10.09028260629235%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="21.756408423075385%" x2="26.093731585586724%" y1="60" y2="60" id="_fb_rtixavqkygzboeurckdt_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="23.925070004331054%" y="71" font-size="12px" id="_fs_rtixavqkygzboeurckdt_ind_7" fill= ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[6]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_cdmypglfidblpizptgqx = '_tp_cdmypglfidblpizptgqx_output_0';
#     document._zoom_cdmypglfidblpizptgqx = undefined;
#     function _output_onclick_cdmypglfidblpizptgqx(i) {
#         var next_id = undefined;
#
#         if (document._zoom_cdmypglfidblpizptgqx !== undefined) {
#             document.getElementById(document._zoom_cdmypglfidblpizptgqx+ '_zoom').style.display = 'none';
#
#             if (document._zoom_cdmypglfidblpizptgqx === '_tp_cdmypglfidblpizptgqx_output_' + i) {
#                 document.getElementById(document._zoom_cdmypglfidblpizptgqx).style.display = 'block';
#                 document.getElementById(document._zoom_cdmypglfidblpizptgqx+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_cdmypglfidblpizptgqx).style.display = 'none';
#                 document.getElementById(document._zoom_cdmypglfidblpizptgqx+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_cdmypglfidblpizptgqx !== '_tp_cdmypglfidblpizptgqx_output_' + i) {
#             next_id = '_tp_cdmypglfidblpizptgqx_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_cdmypglfidblpizptgqx = next_id;
#     }
#     function _output_onmouseover_cdmypglfidblpizptgqx(i, el) {
#         if (document._zoom_cdmypglfidblpizptgqx !== undefined) { return; }
#         if (document._hover_cdmypglfidblpizptgqx !== undefined) {
#             document.getElementById(document._hover_cdmypglfidblpizptgqx + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_cdmypglfidblpizptgqx).style.display = 'none';
#         }
#         document.getElementById('_tp_cdmypglfidblpizptgqx_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_cdmypglfidblpizptgqx = '_tp_cdmypglfidblpizptgqx_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_cdmypglfidblpizptgqx_output_0_name"
#     onclick="_output_onclick_cdmypglfidblpizptgqx(0)"
#     onmouseover="_output_onmouseover_cdmypglfidblpizptgqx(0, this);">They</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_cdmypglfidblpizptgqx_output_1_name"
#     onclick="_output_onclick_cdmypglfidblpizptgqx(1)"
#     onmouseover="_output_onmouseover_cdmypglfidblpizptgqx(1, this);">love</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_cdmypglfidblpizptgqx_output_2_name"
#     onclick="_output_onclick_cdmypglfidblpizptgqx(2)"
#     onmouseover="_output_onmouseover_cdmypglfidblpizptgqx(2, this);">their</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_cdmypglfidblpizptgqx_output_3_name"
#     onclick="_output_onclick_cdmypglfidblpizptgqx(3)"
#     onmouseover="_output_onmouseover_cdmypglfidblpizptgqx(3, this);">vodka</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_cdmypglfidblpizptgqx_output_4_name"
#     onclick="_output_onclick_cdmypglfidblpizptgqx(4)"
#     onmouseover="_output_onmouseover_cdmypglfidblpizptgqx(4, this);">!</div><br><br><div id='_tp_cdmypglfidblpizptgqx_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.82556457570859%" y1="33" x2="47.82556457570859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.82556457570859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="37.34987031040637%" y1="33" x2="37.34987031040637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.34987031040637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="26.87417604510414%" y1="33" x2="26.87417604510414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.87417604510414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="16.398481779801916%" y1="33" x2="16.398481779801916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.398481779801916%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="58.30125884101081%" y1="33" x2="58.30125884101081%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.30125884101081%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="68.77695310631303%" y1="33" x2="68.77695310631303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.77695310631303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="79.25264737161525%" y1="33" x2="79.25264737161525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.25264737161525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="89.72834163691748%" y1="33" x2="89.72834163691748%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.72834163691748%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.746878604975414%" y1="33" x2="34.746878604975414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.746878604975414%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="26.88042592367449%" y1="33" x2="26.88042592367449%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.88042592367449%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.9994</text><text x="26.88042592367449%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-8.9994</text><text x="26.88042592367449%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">They</tspan>(inputs)</text><rect x="18.001914837134766%" width="8.87851108653973%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="22.062394882098417%" x2="26.88042592367449%" y1="60" y2="60" id="_fb_tyuwsxtamzzjjtzlqlps_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="24.471410402886455%" y="71" font-size="12px" id="_fs_tyuwsxtamzzjjtzlqlps_ind_7" fill="rgb(2 ...
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[7]</div>
# </div>
# <div align='center'>
# <script>
#     document._hover_iocepewsswrybykuibyh = '_tp_iocepewsswrybykuibyh_output_0';
#     document._zoom_iocepewsswrybykuibyh = undefined;
#     function _output_onclick_iocepewsswrybykuibyh(i) {
#         var next_id = undefined;
#
#         if (document._zoom_iocepewsswrybykuibyh !== undefined) {
#             document.getElementById(document._zoom_iocepewsswrybykuibyh+ '_zoom').style.display = 'none';
#
#             if (document._zoom_iocepewsswrybykuibyh === '_tp_iocepewsswrybykuibyh_output_' + i) {
#                 document.getElementById(document._zoom_iocepewsswrybykuibyh).style.display = 'block';
#                 document.getElementById(document._zoom_iocepewsswrybykuibyh+'_name').style.background = '#dddddd';
#             } else {
#                 document.getElementById(document._zoom_iocepewsswrybykuibyh).style.display = 'none';
#                 document.getElementById(document._zoom_iocepewsswrybykuibyh+'_name').style.background = '#ffffff';
#             }
#         }
#         if (document._zoom_iocepewsswrybykuibyh !== '_tp_iocepewsswrybykuibyh_output_' + i) {
#             next_id = '_tp_iocepewsswrybykuibyh_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.background = '#bbbbbb';
#         }
#         document._zoom_iocepewsswrybykuibyh = next_id;
#     }
#     function _output_onmouseover_iocepewsswrybykuibyh(i, el) {
#         if (document._zoom_iocepewsswrybykuibyh !== undefined) { return; }
#         if (document._hover_iocepewsswrybykuibyh !== undefined) {
#             document.getElementById(document._hover_iocepewsswrybykuibyh + '_name').style.background = '#ffffff';
#             document.getElementById(document._hover_iocepewsswrybykuibyh).style.display = 'none';
#         }
#         document.getElementById('_tp_iocepewsswrybykuibyh_output_' + i).style.display = 'block';
#         el.style.background = '#dddddd';
#         document._hover_iocepewsswrybykuibyh = '_tp_iocepewsswrybykuibyh_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; background: #dddddd; border-radius: 3px; padding: 0px" id="_tp_iocepewsswrybykuibyh_output_0_name"
#     onclick="_output_onclick_iocepewsswrybykuibyh(0)"
#     onmouseover="_output_onmouseover_iocepewsswrybykuibyh(0, this);">They</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_iocepewsswrybykuibyh_output_1_name"
#     onclick="_output_onclick_iocepewsswrybykuibyh(1)"
#     onmouseover="_output_onmouseover_iocepewsswrybykuibyh(1, this);">love</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_iocepewsswrybykuibyh_output_2_name"
#     onclick="_output_onclick_iocepewsswrybykuibyh(2)"
#     onmouseover="_output_onmouseover_iocepewsswrybykuibyh(2, this);">their</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_iocepewsswrybykuibyh_output_3_name"
#     onclick="_output_onclick_iocepewsswrybykuibyh(3)"
#     onmouseover="_output_onmouseover_iocepewsswrybykuibyh(3, this);">vodka</div>
# <div style="display: inline; background: #ffffff; border-radius: 3px; padding: 0px" id="_tp_iocepewsswrybykuibyh_output_4_name"
#     onclick="_output_onclick_iocepewsswrybykuibyh(4)"
#     onmouseover="_output_onmouseover_iocepewsswrybykuibyh(4, this);">!</div><br><br><div id='_tp_iocepewsswrybykuibyh_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="47.82556457570859%" y1="33" x2="47.82556457570859%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="47.82556457570859%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-7</text><line x1="37.34987031040637%" y1="33" x2="37.34987031040637%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="37.34987031040637%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8</text><line x1="26.87417604510414%" y1="33" x2="26.87417604510414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.87417604510414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="16.398481779801916%" y1="33" x2="16.398481779801916%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="16.398481779801916%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-10</text><line x1="58.30125884101081%" y1="33" x2="58.30125884101081%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="58.30125884101081%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="68.77695310631303%" y1="33" x2="68.77695310631303%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="68.77695310631303%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-5</text><line x1="79.25264737161525%" y1="33" x2="79.25264737161525%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="79.25264737161525%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-4</text><line x1="89.72834163691748%" y1="33" x2="89.72834163691748%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="89.72834163691748%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-3</text><line x1="34.746878604975414%" y1="33" x2="34.746878604975414%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="34.746878604975414%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-8.24848</text><text x="34.746878604975414%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">base value</text><line x1="30.744369425611254%" y1="33" x2="30.744369425611254%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="30.744369425611254%" y="27" font-size="13px" style="stroke:#ffffff;stroke-width:8px;" font-weight="bold" fill="rgb(255,255,255)" dominant-baseline="bottom" text-anchor="middle">-8.63055</text><text x="30.744369425611254%" y="27" font-size="13px" font-weight="bold" fill="rgb(0,0,0)" dominant-baseline="bottom" text-anchor="middle">-8.63055</text><text x="30.744369425611254%" y="10" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">f<tspan baseline-shift="sub" font-size="8px">They</tspan>(inputs)</text><rect x="24.4301180758367%" width="6.314251349774551%" y="40" height="18" style="fill:rgb(255.0, 0.0, 81.08083606031792); stroke-width:0; stroke:rgb(0,0,0)" /><line x1="26.822438612528938%" x2="30.744369425611254%" y1="60" y2="60" id="_fb_mhkvlmmjhbnewcfgcfty_ind_7" style="stroke:rgb(255.0, 0.0, 81.08083606031792);stroke-width:2; opacity: 0"/><text x="28.783404019070097%" y="71" font-size="12px" id="_fs_mhkvlmmjhbnewcfgcfty_ind_7" fill ...

# %% [markdown]
# To view what input tokens impact (positively/negatively) the liklihood of generating the word "vodka", we plot the global token importances the word "vodka". <br><br>
#
# Voila! Russians love their vodka, dont they? :)

# %%
shap.plots.bar(shap_values[0, :, "vodka"])

# %% [markdown]
# <hr>
# Have an idea for more helpful examples? Pull requests that add to this documentation notebook are encouraged!
